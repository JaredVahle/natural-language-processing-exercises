# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
response = requests.get('https://web-scraping-demo.zgulde.net/news')

# %%
soup = BeautifulSoup(response.text)

# %%
def parse_news_article(article):
    title = article.h2.text
    date, author = article.select('.italic')[0].find_all('p')
    explination = article.select('p')[2]
    return {'title':title,'date':date,'author':author.text,'explination':explination.text}

# %%
articles = soup.select('.grid.gap-y-12 > div')

# %%
articles
# Out:
# [<div class="grid grid-cols-4 gap-x-4 border rounded pr-3 bg-green-50 hover:shadow-lg transition duration-500">
#  <img src="/static/placeholder.png"/>
#  <div class="col-span-3 space-y-3 py-3">
#  <h2 class="text-2xl text-green-900">leader table head</h2>
#  <div class="grid grid-cols-2 italic">
#  <p> 1994-07-10 </p>
#  <p class="text-right">By Jill Golden </p>
#  </div>
#  <p>Not rock hot. Two trip fall follow clear letter.
#  Student style other end. Daughter quickly billion brother require.</p>
#  </div>
#  </div>,
#  <div class="grid grid-cols-4 gap-x-4 border rounded pr-3 bg-green-50 hover:shadow-lg transition duration-500">
#  <img src="/static/placeholder.png"/>
#  <div class="col-span-3 space-y-3 py-3">
#  <h2 class="text-2xl text-green-900">want art attack</h2>
#  <div class="grid grid-cols-2 italic">
#  <p> 1987-02-24 </p>
#  <p class="text-right">By Rick Rodgers </p>
#  </div>
#  <p>Society expert part power be ground social control. Fund thing student raise senior.
#  Pattern build skin be way. Body who care along. Take office who.</p>
#  </div>
#  </div>,
#  <div class="grid grid-cols-4 gap-x-4 border rounded pr-3 bg-green-50 hover:shadow-lg transition duration-500">
#  <img src="/static/placeholder.png"/>
#  <div class="col-span-3 space-y-3 py-3">
#  <h2 class="text-2xl text-green-900">past thus that</h2>
#  <div class="grid grid-cols-2 italic">
#  <p> 2002-03-30 </p>
#  <p class="text-right">By Paul Burch </p>
#  </div>
#  <p>Cultural there arm blood top employee president.
#  Summer board task away environmental mother. Guess question score within record accept.</p>
#  </div>
#  </div>,
#  <div class="grid grid-cols-4 gap-x-4 border rounded pr-3 bg-green-50 hover:shadow-lg transition duration-500">
#  <img src="/static/placeholder.png"/>
#  <div class="col-span-3 space-y-3 py-3">
#  <h2 class="text-2xl text-green-900">assume key arm</h2>
#  <div class="grid grid-cols-2 italic">
#  <p> 1978-02-19 </p>
#  <p class="text-right">By Linda Holt </p>
#  </div>
#  <p>Writer reach adult administration. Performance much short agree collection laugh need. Fund of Republican much show success current effect.
#  Window day hear risk whole stand pretty hand. Argue defense player different lead get fear. Resource mouth center color.</p>
#  </div>
#  </div>,
#  <div class="grid grid-cols-4 gap-x-4 border rounded pr-3 bg-green-50 hover:shadow-lg transition duration-500">
#  <img src="/static/placeholder.png"/>
#  <div class="col-span-3 space-y-3 py-3">
#  <h2 class="text-2xl text-green-900">skin society half</h2>
#  <div class="grid grid-cols-2 italic">
#  <p> 1974-05-03 </p>
#  <p class="text-right">By Kyle Taylor </p>
#  </div>
#  <p>Quickly old pattern know.
#  Single treat mention listen hold five provide. Generation security window reduce seven together international. Just beat job mean.</p>
#  </div>
#  </div>,
#  <div class="grid grid-cols-4 gap-x-4 border rounded pr-3 bg-green-50 hover:shadow-lg transition duration-500">
#  <img src="/static/placeholder.png"/>
#  <div class="col-span-3 space-y-3 py-3">
#  <h2 class="text-2xl text-green-900">member make opportunity</h2>
#  <div class="grid grid-cols-2 italic">
#  <p> 1983-12-20 </p>
#  <p class="text-right">By Victoria Garcia </p>
#  </div>
#  <p>Soldier star several manage wall sound. Five indicate political threat purpose drug.
#  Yes administration make could appear five yeah. Question young by cover think data he experience. Occur what see tree still.</p>
#  </div>
#  </div>,
#  <div class="grid grid-cols-4 gap-x-4 border rounded pr-3 bg-green-50 hover:shadow-lg transition duration-500">
#  <img src="/static/placeholder.png"/>
#  <div class="col-span-3 space-y-3 py-3">
#  <h2 class="text-2xl text-green-900">section another pass</h2>
#  <div class="grid grid-cols-2 italic">
#  <p> 1970-02-01 </p>
#  <p class="text-right">By Timothy Macdonald </p>
#  </div>
#  <p>Field forward doctor worker need several particularly. Tough table relate future common race.
#  Black several move price call rather spend will. Simple daughter front simply. Edge local color story short imagine let. Best decision tend as.</p>
#  </div>
#  </div>,
#  <div class="grid grid-cols-4 gap-x-4 border rounded pr-3 bg-green-50 hover:shadow-lg transition duration-500">
#  <img src="/static/placeholder.png"/>
#  <div class="col-span-3 space-y-3 py-3">
#  <h2 class="text-2xl text-green-900">reach over even</h2>
#  <div class="grid grid-cols-2 italic">
#  <p> 1997-11-17 </p>
#  <p class="text-right">By Frank Snow </p>
#  </div>
#  <p>There need point organization issue water war dinner. Try very fear treatment father laugh.
#  Matter door role PM fall worry late. Course student college onto.</p>
#  </div>
#  </div>,
#  <div class="grid grid-cols-4 gap-x-4 border rounded pr-3 bg-green-50 hover:shadow-lg transition duration-500">
#  <img src="/static/placeholder.png"/>
#  <div class="col-span-3 space-y-3 py-3">
#  <h2 class="text-2xl text-green-900">per article then</h2>
#  <div class="grid grid-cols-2 italic">
#  <p> 2009-05-05 </p>
#  <p class="text-right">By Andrew Lynch </p>
#  </div>
#  <p>Pick letter food son page language. Defense read first write.
#  Something leg generation tough culture. Rather month garden improve majority indeed American. Individual response build include project tree produce. Subject front film enter.</p>
#  </div>
#  </div>,
#  <div class="grid grid-cols-4 gap-x-4 border rounded pr-3 bg-green-50 hover:shadow-lg transition duration-500">
#  <img src="/static/placeholder.png"/>
#  <div class="col-span-3 space-y-3 py-3">
#  <h2 class="text-2xl text-green-900">represent sing today</h2>
#  <div class="grid grid-cols-2 italic">
#  <p> 1974-09-24 </p>
#  <p class="text-right">By Richard Brown </p>
#  </div>
#  <p>Serve face quite former behind design significant. Interest possible reality similar blue now go.
#  Truth road we. Blue improve position personal democratic various way shake.</p>
#  </div>
#  </div>,
#  <div class="grid grid-cols-4 gap-x-4 border rounded pr-3 bg-green-50 hover:shadow-lg transition duration-500">
#  <img src="/static/placeholder.png"/>
#  <div class="col-span-3 space-y-3 py-3">
#  <h2 class="text-2xl text-green-900">child administration form</h2>
#  <div class="grid grid-cols-2 italic">
#  <p> 1975-12-07 </p>
#  <p class="text-right">By Shane Scott </p>
#  </div>
#  <p>Call play note tonight small. Life president role.
#  Chair interest institution become nearly remain. Identify whom bar from apply.</p>
#  </div>
#  </div>,
#  <div class="grid grid-cols-4 gap-x-4 border rounded pr-3 bg-green-50 hover:shadow-lg transition duration-500">
#  <img src="/static/placeholder.png"/>
#  <div class="col-span-3 space-y-3 py-3">
#  <h2 class="text-2xl text-green-900">modern meet material</h2>
#  <div class="grid grid-cols-2 italic">
#  <p> 1999-08-06 </p>
#  <p class="text-right">By Mrs. Lori Torres </p>
#  </div>
#  <p>Message nature focus opportunity thus throughout investment think. Medical present knowledge smile. Media sell approach professional.
#  Bring purpose future crime candidate similar. Whom student place change put technology. Husband reveal building down deep office later hair.</p>
#  </div>
#  </div>]

# %%
article = articles[0]

# %%
article.select('p')[2]
# Out:
# <p>Not rock hot. Two trip fall follow clear letter.
# Student style other end. Daughter quickly billion brother require.</p>

# %%
pd.DataFrame([parse_news_article(article) for article in articles])
# Out:
#                         title            date                 author  \
# 0           leader table head  [ 1994-07-10 ]        By Jill Golden
# 1             want art attack  [ 1987-02-24 ]       By Rick Rodgers
# 2              past thus that  [ 2002-03-30 ]         By Paul Burch
# 3              assume key arm  [ 1978-02-19 ]         By Linda Holt
# 4           skin society half  [ 1974-05-03 ]        By Kyle Taylor
# 5     member make opportunity  [ 1983-12-20 ]    By Victoria Garcia
# 6        section another pass  [ 1970-02-01 ]  By Timothy Macdonald
# 7             reach over even  [ 1997-11-17 ]         By Frank Snow
# 8            per article then  [ 2009-05-05 ]       By Andrew Lynch
# 9        represent sing today  [ 1974-09-24 ]      By Richard Brown
# 10  child administration form  [ 1975-12-07 ]        By Shane Scott
# 11       modern meet material  [ 1999-08-06 ]   By Mrs. Lori Torres
#
#                                           explination
# 0   Not rock hot. Two trip fall follow clear lette...
# 1   Society expert part power be ground social con...
# 2   Cultural there arm blood top employee presiden...
# 3   Writer reach adult administration. Performance...
# 4   Quickly old pattern know.\nSingle treat mentio...
# 5   Soldier star several manage wall sound. Five i...
# 6   Field forward doctor worker need several parti...
# 7   There need point organization issue water war ...
# 8   Pick letter food son page language. Defense re...
# 9   Serve face quite former behind design signific...
# 10  Call play note tonight small. Life president r...
# 11  Message nature focus opportunity thus througho...
